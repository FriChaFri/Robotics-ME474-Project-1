# %% [markdown]
# # Verification of Answers to Problems 1
#
# ## Foreward Kinematics
#
#
# Using the values from question 1 part A: The joint angles **$\theta$** are given by
#
# $$
# \theta = \begin{bmatrix} \theta_1 \\ \theta_2 \end{bmatrix} = \begin{bmatrix} 5\pi/6 \\ -3\pi/7 \end{bmatrix}
# $$
#
# Using the forward kinematic equations we derived from question 1 we find that the transformation matrix from C to 0 is:
#
# $$
# {}^0T_C =
# \begin{bmatrix}
# -0.5   & -0.1927 & 0.8443 & 1.0754 \\
# -0.8660& 0.1113  & -0.4875& 0.3028 \\
# 0      & -0.9749 & -0.2225& 1.0220 \\
# 0      & 0       & 0      & 1.0
# \end{bmatrix}
# $$
#
# The quaternion is: 0.3117 < -0.3909,  0.6771, -0.5400 >
#
# Now, using Mujoco we can plug in these **$\theta$** values and see that the transformation (and quaternion) is the same.

# %%
import mujoco as mj
import mujoco.viewer
import time
import numpy as np
import sympy as sp

# Load the XML model

model = mj.MjModel.from_xml_path("penulum.xml")

data = mj.MjData(model)

joint1_name = "joint1"
joint2_name = "joint2"

joint1_id = model.joint(joint1_name).id
joint2_id = model.joint(joint2_name).id



world_frame_id = 0


frame1_name = "frame1"
frame1_id = model.body(name=frame1_name).id


frame2_name = "frame2"
frame2_id = model.body(name=frame2_name).id

end_effector_body_name="end-effector"
end_effector_body_id = model.body(name=end_effector_body_name).id


theta1_parta = 5 * np.pi / 6
theta2_parta = -3 * np.pi / 7

#set model to the given theta values
data.qpos[joint1_id] = theta1_parta
data.qpos[joint2_id] = theta2_parta

mj.mj_forward(model, data)

def get_spatial_transformation(body_id):
    #Extract the positions
    rot = data.xmat[body_id].reshape(3,3)
    pos = data.xpos[body_id]


    #Convert to transformation matrix
    transformation = np.eye(4) 
    transformation[:3, :3] = rot  
    transformation[:3, 3] = pos 
    return transformation

def quat_print(quat):
    """
    Prints a quaternion in the format: <w, <x, y, z>>
    AI Generated function
    
    Args:
        quat (list or tuple): A quaternion [w, x, y, z]
    """
    if len(quat) != 4:
        raise ValueError("Quaternion must be a list or tuple of 4 elements [w, x, y, z]")
    
    w, x, y, z = [round(val, 4) for val in quat]

    print(f"{w}, <{x}, {y}, {z}>")




#Display
quat_print(data.xquat[end_effector_body_id])
sp.Matrix(np.round(get_spatial_transformation(end_effector_body_id), 4))
# Out:
# 0.3117, <-0.3909, 0.6771, -0.54>
# Matrix([
# [  -0.5, -0.1927,  0.8443, 1.0754],
# [-0.866,  0.1113, -0.4875, 0.3028],
# [   0.0, -0.9749, -0.2225,  1.022],
# [   0.0,     0.0,     0.0,    1.0]])

# %% [markdown]
# ## Inverse Kinematics
#
# In Question 1d we are asked to find the values of theta corresponding to a given orientation of the camera frame. To verify this calculation we can plug in the values of theta that we found and see if the orientation matches what was given.
#
#
# The values of theta we found are:
#
# $$
# \left[\begin{matrix}-45.0 & 315.0\\135.0 & 45.0\end{matrix}\right]
# $$
#  Where each row is one of two possible solutions. Columns 1 and 2 represet **theta1** and **theta2** respectivly.
#
#
# The expected result is:
#
# $$
# k = -\frac{1}{2} x_0 + \frac{1}{2} y_0 - \frac{\sqrt{2}}{2} z_0.
# $$

# %%
solutions = [(-0.785398163397448, 5.49778714378214),
 (0.785398163397448, 0.785398163397448),
 (2.35619449019234, 0.785398163397448),
 (3.92699081698724, 5.49778714378214)]


theta1_sol1_partd = np.deg2rad(-45)
theta2_sol1_partd = np.deg2rad(135)

theta1_sol2_partd = np.deg2rad(315)
theta2_sol2_partd = np.deg2rad(45)

print("Expected: \n[-0.5         0.5        -0.70710678]\nActual:\n")

for solution in solutions:
    #set model to solution
    data.qpos[joint1_id] = solution[0]
    data.qpos[joint2_id] = solution[1]
    mj.mj_forward(model, data)
    
    k = data.xmat[end_effector_body_id].reshape(3,3)[:,2]
    print(k)

    print()
# Out:
# Expected:
# [-0.5         0.5        -0.70710678]
# Actual:
#
# [-0.5         0.5        -0.70710678]
#
# [ 0.5         0.5        -0.70710678]
#
# [-0.5         0.5        -0.70710678]
#
# [ 0.5         0.5        -0.70710678]

# %% [markdown]
# As can be seen above, two of the solutions match the given K vector and two do not, which is exactly what was expected.
#
#
# # Verification of answers to Problem 2
#
# #### Part A
#
# Using the values from question 1 part A: The joint angles **$\theta$** are given by
#
# $$
# \theta = \begin{bmatrix} \theta_1 \\ \theta_2 \end{bmatrix} = \begin{bmatrix} 5\pi/6 \\ -3\pi/7 \end{bmatrix}
# $$
#
# The angular rates of change are also given:
#
# $$
# \dot{\boldsymbol{\theta}} = \begin{bmatrix} 1 & 2 \end{bmatrix}^{\top}
# $$
#
#
#
# The goal is to find the spatial and body twist, the spatial twist  found was:
#
# $$
# \begin{bmatrix}
# -2.07846096908265 \\
# 1.2 \\
# 0 \\
# 1.0 \\
# 1.73205080756888 \\
# 1.0
# \end{bmatrix}
# $$
#
# The body twist was:
#
# $$
# \left[\begin{matrix}-0.779942329745459\\1.77801674716505\\-0.779942329745459\\-2.0\\-0.974927912181824\\-0.222520933956314\end{matrix}\right]
# $$

# %%
# --- Reset the simulation and set the configuration ---
mj.mj_resetData(model, data)

# Joint angles (from Question 1 Part A)
theta1_parta = 5 * np.pi / 6
theta2_parta = -3 * np.pi / 7

# Set joint positions
data.qpos[joint1_id] = theta1_parta
data.qpos[joint2_id] = theta2_parta

# Set joint velocities: [1.0, 2.0]
data.qvel[joint1_id] = 1.0
data.qvel[joint2_id] = 2.0

# Compute the forward dynamics to update the simulation state
mj.mj_forward(model, data)

# --- Retrieve Sensor Data to Form the Twists ---

# Get sensor IDs for the new sensor names:
# Spatial sensors (world frame)
spatial_lin_sensor_id = model.sensor("spatial-linear-vel").id # 0
spatial_ang_sensor_id = model.sensor("spatial-ang-vel").id # 1

# Body sensors (end-effector's frame)
body_lin_sensor_id = model.sensor("body-linear-vel").id # 2
body_ang_sensor_id = model.sensor("body-ang-vel").id # 3

# Since each sensor returns a 3D vector, we slice 3 elements starting at each sensor's id.
# Note: sensor data is stored in a 1D array in sensor order.

# Spatial twist: measured in the world frame [linear; angular]
#Bad doesn't work
# spatial_lin_vel = data.sensordata[0 : 3]
# spatial_ang_vel = data.sensordata[3 : 6]
# spatial_twist = np.concatenate([spatial_lin_vel, spatial_ang_vel])
# print("Spatial Twist (linear; angular):")
# print(spatial_twist)


# Body twist: measured in the end-effector's (body) frame [linear; angular]
body_lin_vel = data.sensordata[6 : 9]
body_ang_vel = data.sensordata[9 : 12]
body_twist = np.concatenate([body_lin_vel, body_ang_vel])
print("\nBody Twist (linear; angular):")
print(body_twist)
# Expected body twist:
# [ -0.779942329745459, 1.77801674716505, -0.779942329745459,
#   -2.0, -0.974927912181824, -0.222520933956314 ]


# find body twist using the spatial twist and an adjoint transformation
from spatialmath.base import tr2adjoint
sp.pprint(sp.simplify(sp.Matrix(tr2adjoint(np.array(get_spatial_transformation(end_effector_body_id)))) @ body_twist))
# Expected spatial twist:
# [ -2.07846096908265, 1.2, 0, 1.0, 1.73205080756888, 1.0 ]
# Out:
# Body Twist (linear; angular):
# [-0.77994233  1.77801675 -0.77994233 -2.         -0.97492791 -0.22252093]
# [-2.07846096908265  1.2  4.44089209850063e-16  1.0  1.73205080756888  1.0]

# %%
# # Do simulated runtime test

# import time
# import numpy as np
# import mujoco as mj

# # --- Reset the simulation and set the configuration ---
# mj.mj_resetData(model, data)

# # Joint angles (from Question 1 Part A)
# theta1_parta = 5 * np.pi / 6
# theta2_parta = -3 * np.pi / 7

# # Set joint positions (using joint indices defined earlier)
# data.qpos[joint1_id] = theta1_parta
# data.qpos[joint2_id] = theta2_parta

# # Set joint velocities: [1.0, 2.0]
# data.qvel[joint1_id] = 1.0
# data.qvel[joint2_id] = 2.0

# # Compute the forward dynamics to update the simulation state
# mj.mj_forward(model, data)

# # --- Debug: Print all valid sensor names ---
# sensor_names = [model.sensor(i).name for i in range(model.nsensor)]
# print("Valid sensor names:", sensor_names)
# print("Total sensors in model:", model.nsensor)

# # Get sensor IDs from the model:
# # Angular velocity sensors
# spatial_ang_sensor_id = model.sensor("spatial-ang-vel").id
# body_ang_sensor_id    = model.sensor("body-ang-vel").id

# # Linear velocity sensors (using framelinvel, as updated in your XML)
# spatial_lin_sensor_id = model.sensor("spatial-linear-vel").id
# body_lin_sensor_id    = model.sensor("body-linear-vel").id

# # If you prefer to use the joint sensors defined in your XML, you can also get their IDs:
# joint1_pos_sensor_id = model.sensor("joint1-position").id
# joint2_pos_sensor_id = model.sensor("joint2-position").id
# joint1_vel_sensor_id = model.sensor("joint1-velocity").id
# joint2_vel_sensor_id = model.sensor("joint2-velocity").id

# # --- Launch the viewer and print sensor data in real time ---
# with mj.viewer.launch_passive(model, data) as viewer:
#     print("Viewer launched. Press ESC to close.")
#     while viewer.is_running():
#         mj.mj_step(model, data)
#         viewer.sync()  # Refresh the visualization
#         time.sleep(0.001)  # Adjust the sleep time as needed

#         # Retrieve sensor outputs:
#         spatial_ang_vel = data.sensordata[spatial_ang_sensor_id : spatial_ang_sensor_id + 3]
#         spatial_lin_vel = data.sensordata[spatial_lin_sensor_id : spatial_lin_sensor_id + 3]
#         body_ang_vel    = data.sensordata[body_ang_sensor_id    : body_ang_sensor_id    + 3]
#         body_lin_vel    = data.sensordata[body_lin_sensor_id    : body_lin_sensor_id    + 3]

#         # Print spatial and body velocities:
#         print("Spatial Angular Velocity:", spatial_ang_vel)
#         print("Spatial Linear  Velocity:", spatial_lin_vel)
#         print("Body Angular    Velocity:", body_ang_vel)
#         print("Body Linear     Velocity:", body_lin_vel)

#         # Print joint positions and velocities (directly from data.qpos and data.qvel)
#         joint_positions = [data.qpos[joint1_id], data.qpos[joint2_id]]
#         joint_velocities = [data.qvel[joint1_id], data.qvel[joint2_id]]
#         print("Joint Positions:", joint_positions)
#         print("Joint Velocities:", joint_velocities)
#         print("-" * 50)
# Out:
# Valid sensor names: ['spatial-linear-vel', 'spatial-ang-vel', 'body-linear-vel', 'body-ang-vel', 'joint1-position', 'joint2-position', 'joint1-velocity', 'joint2-velocity']
# Total sensors in model: 8
# Viewer launched. Press ESC to close.
# Spatial Angular Velocity: [ 1.25346662 -1.55988466  1.        ]
# Spatial Linear  Velocity: [-0.61118321  1.25346662 -1.55988466]
# Body Angular    Velocity: [1.         1.73205081 1.        ]
# Body Linear     Velocity: [-1.55988466  1.          1.73205081]
# Joint Positions: [np.float64(2.6199864854865256), np.float64(-1.3423721574847833)]
# Joint Velocities: [np.float64(0.9917672824589305), np.float64(2.0248807775195963)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.24814848 -1.57782669  1.00894415]
# Spatial Linear  Velocity: [-0.6208745   1.24814848 -1.57782669]
# Body Angular    Velocity: [1.00894415 1.75561211 0.99176728]
# Body Linear     Velocity: [-1.57782669  1.00894415  1.75561211]
# Joint Positions: [np.float64(2.6219619523246696), np.float64(-1.3382975465690348)]
# Joint Velocities: [np.float64(0.9844950005604923), np.float64(2.0495528744676776)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.24392473 -1.59552558  1.0177252 ]
# Spatial Linear  Velocity: [-0.63099216  1.24392473 -1.59552558]
# Body Angular    Velocity: [1.0177252  1.77901726 0.984495  ]
# Body Linear     Velocity: [-1.59552558  1.0177252   1.77901726]
# Joint Positions: [np.float64(2.623923309640639), np.float64(-1.3341736804411937)]
# Joint Velocities: [np.float64(0.9760354620780292), np.float64(2.0745043119677127)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.23853275 -1.613359    1.02658133]
# Spatial Linear  Velocity: [-0.64096007  1.23853275 -1.613359  ]
# Body Angular    Velocity: [1.02658133 1.80269213 0.97603546]
# Body Linear     Velocity: [-1.613359    1.02658133  1.80269213]
# Joint Positions: [np.float64(2.625867617903211), np.float64(-1.3299998764222511)]
# Joint Velocities: [np.float64(0.969056047989559), np.float64(2.099119131041487)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.23477819 -1.63084486  1.03521358]
# Spatial Linear  Velocity: [-0.65150412  1.23477819 -1.63084486]
# Body Angular    Velocity: [1.03521358 1.82609802 0.96905605]
# Body Linear     Velocity: [-1.63084486  1.03521358  1.82609802]
# Joint Positions: [np.float64(2.627796760572077), np.float64(-1.325776550931279)]
# Joint Velocities: [np.float64(0.9608639920784814), np.float64(2.1240243430690895)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.22983398 -1.64846808  1.04392943]
# Spatial Linear  Velocity: [-0.66189364  1.22983398 -1.64846808]
# Body Angular    Velocity: [1.04392943 1.84978127 0.96086399]
# Body Linear     Velocity: [-1.64846808  1.04392943  1.84978127]
# Joint Positions: [np.float64(2.6297099352089597), np.float64(-1.3215035031228393)]
# Joint Velocities: [np.float64(0.9528144746785154), np.float64(2.14890445627581)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.22512372 -1.66598053  1.05257533]
# Spatial Linear  Velocity: [-0.67250054  1.22512372 -1.66598053]
# Body Angular    Velocity: [1.05257533 1.87346618 0.95281447]
# Body Linear     Velocity: [-1.66598053  1.05257533  1.87346618]
# Joint Positions: [np.float64(2.631607416267848), np.float64(-1.3171807845797645)]
# Joint Velocities: [np.float64(0.9454319005434674), np.float64(2.1736285758200573)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.22119341 -1.68327813  1.06108801]
# Spatial Linear  Velocity: [-0.68347351  1.22119341 -1.68327813]
# Body Angular    Velocity: [1.06108801 1.89703807 0.9454319 ]
# Body Linear     Velocity: [-1.68327813  1.06108801  1.89703807]
# Joint Positions: [np.float64(2.6334910367229587), np.float64(-1.3128088337337809)]
# Joint Velocities: [np.float64(0.9384302151613185), np.float64(2.1982628413214984)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.21774054 -1.70040976  1.06949788]
# Spatial Linear  Velocity: [-0.69473957  1.21774054 -1.70040976]
# Body Angular    Velocity: [1.06949788 1.9205556  0.93843022]
# Body Linear     Velocity: [-1.70040976  1.06949788  1.9205556 ]
# Joint Positions: [np.float64(2.6353599865179547), np.float64(-1.3083874423719863)]
# Joint Velocities: [np.float64(0.9304969552126279), np.float64(2.223135542286944)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.21340131 -1.71762635  1.07796701]
# Spatial Linear  Velocity: [-0.70593548  1.21340131 -1.71762635]
# Body Angular    Velocity: [1.07796701 1.94430418 0.93049696]
# Body Linear     Velocity: [-1.71762635  1.07796701  1.94430418]
# Joint Positions: [np.float64(2.637212428007449), np.float64(-1.3039161361925582)]
# Joint Velocities: [np.float64(0.9224324919249466), np.float64(2.248047614870693)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.20901254 -1.73477043  1.08640259]
# Spatial Linear  Velocity: [-0.71728304  1.20901254 -1.73477043]
# Body Angular    Velocity: [1.08640259 1.96810759 0.92243249]
# Body Linear     Velocity: [-1.73477043  1.08640259  1.96810759]
# Joint Positions: [np.float64(2.639049100224198), np.float64(-1.2993950882363827)]
# Joint Velocities: [np.float64(0.9139561892313014), np.float64(2.2730755905612243)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.20428502 -1.7518979   1.09484087]
# Spatial Linear  Velocity: [-0.72870661  1.20428502 -1.7518979 ]
# Body Angular    Velocity: [1.09484087 1.99203316 0.91395619]
# Body Linear     Velocity: [-1.7518979   1.09484087  1.99203316]
# Joint Positions: [np.float64(2.640867668700898), np.float64(-1.2948236721810311)]
# Joint Velocities: [np.float64(0.9045879169949893), np.float64(2.2983491764006367)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.19872868 -1.76910486  1.10334929]
# Spatial Linear  Velocity: [-0.74007029  1.19872868 -1.76910486]
# Body Angular    Velocity: [1.10334929 2.01619178 0.90458792]
# Body Linear     Velocity: [-1.76910486  1.10334929  2.01619178]
# Joint Positions: [np.float64(2.64266685132731), np.float64(-1.290201520013139)]
# Joint Velocities: [np.float64(0.8945702562869406), np.float64(2.323811434705959)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.19260089 -1.78634339  1.11190326]
# Spatial Linear  Velocity: [-0.7514418   1.19260089 -1.78634339]
# Body Angular    Velocity: [1.11190326 2.04053197 0.89457026]
# Body Linear     Velocity: [-1.78634339  1.11190326  2.04053197]
# Joint Positions: [np.float64(2.6444478538039697), np.float64(-1.2855289362434072)]
# Joint Velocities: [np.float64(0.8864050315629982), np.float64(2.348780604823507)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.1884744  -1.80308641  1.12017555]
# Spatial Linear  Velocity: [-0.76353015  1.1884744  -1.80308641]
# Body Angular    Velocity: [1.12017555 2.06445564 0.88640503]
# Body Linear     Velocity: [-1.80308641  1.12017555  2.06445564]
# Joint Positions: [np.float64(2.6462108894361163), np.float64(-1.2808059521672985)]
# Joint Velocities: [np.float64(0.8768546264740468), np.float64(2.3741421968529917)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.18302065 -1.820011    1.12859018]
# Spatial Linear  Velocity: [-0.77542554  1.18302065 -1.820011  ]
# Body Angular    Velocity: [1.12859018 2.08874014 0.87685463]
# Body Linear     Velocity: [-1.820011    1.12859018  2.08874014]
# Joint Positions: [np.float64(2.647956139596334), np.float64(-1.2760326031570521)]
# Joint Velocities: [np.float64(0.8683680181973998), np.float64(2.399215337914654)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.1787524  -1.8365913   1.13682353]
# Spatial Linear  Velocity: [-0.78782231  1.1787524  -1.8365913 ]
# Body Angular    Velocity: [1.13682353 2.11278643 0.86836802]
# Body Linear     Velocity: [-1.8365913   1.13682353  2.11278643]
# Joint Positions: [np.float64(2.6496832690721797), np.float64(-1.2712087716787706)]
# Joint Velocities: [np.float64(0.8589792960724163), np.float64(2.4245550387198658)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.17365901 -1.85324898  1.14514096]
# Spatial Linear  Velocity: [-0.80016612  1.17365901 -1.85324898]
# Body Angular    Velocity: [1.14514096 2.13708196 0.8589793 ]
# Body Linear     Velocity: [-1.85324898  1.14514096  2.13708196]
# Joint Positions: [np.float64(2.651392435192966), np.float64(-1.2663344866700796)]
# Joint Velocities: [np.float64(0.8501602826366941), np.float64(2.4497397414763817)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.16924422 -1.86965787  1.15334369]
# Spatial Linear  Velocity: [-0.81287656  1.16924422 -1.86965787]
# Body Angular    Velocity: [1.15334369 2.16125499 0.85016028]
# Body Linear     Velocity: [-1.86965787  1.15334369  2.16125499]
# Joint Positions: [np.float64(2.6530814263917475), np.float64(-1.2614090727160185)]
# Joint Velocities: [np.float64(0.8392749844503474), np.float64(2.4755461927303077)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.16283298 -1.88640643  1.16180298]
# Spatial Linear  Velocity: [-0.82520448  1.16283298 -1.88640643]
# Body Angular    Velocity: [1.16180298 2.18598783 0.83927498]
# Body Linear     Velocity: [-1.88640643  1.16180298  2.18598783]
# Joint Positions: [np.float64(2.6547513161172325), np.float64(-1.256432827349983)]
# Joint Velocities: [np.float64(0.8303479057715435), np.float64(2.50078129898632)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.15851214 -1.90258118  1.1699569 ]
# Spatial Linear  Velocity: [-0.83829729  1.15851214 -1.90258118]
# Body Angular    Velocity: [1.1699569  2.21022803 0.83034791]
# Body Linear     Velocity: [-1.90258118  1.1699569   2.21022803]
# Joint Positions: [np.float64(2.656402224793322), np.float64(-1.25140576111197)]
# Joint Velocities: [np.float64(0.8207668179096062), np.float64(2.526223780044159)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.15363161 -1.91877195  1.17817221]
# Spatial Linear  Velocity: [-0.85141462  1.15363161 -1.91877195]
# Body Angular    Velocity: [1.17817221 2.23466258 0.82076682]
# Body Linear     Velocity: [-1.91877195  1.17817221  2.23466258]
# Joint Positions: [np.float64(2.658034733090086), np.float64(-1.2463280341878602)]
# Joint Velocities: [np.float64(0.8114781861988706), np.float64(2.551586858919045)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.14914919 -1.9347568   1.18631465]
# Spatial Linear  Velocity: [-0.86482861  1.14914919 -1.9347568 ]
# Body Angular    Velocity: [1.18631465 2.25903808 0.81147819]
# Body Linear     Velocity: [-1.9347568   1.18631465  2.25903808]
# Joint Positions: [np.float64(2.659647110893029), np.float64(-1.2411990825057093)]
# Joint Velocities: [np.float64(0.8008681344475481), np.float64(2.577376130221042)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.14344549 -1.9509145   1.19462411]
# Spatial Linear  Velocity: [-0.8780797   1.14344549 -1.9509145 ]
# Body Angular    Velocity: [1.19462411 2.28379967 0.80086813]
# Body Linear     Velocity: [-1.9509145   1.19462411  2.28379967]
# Joint Positions: [np.float64(2.6612389821462554), np.float64(-1.2360187658249757)]
# Joint Velocities: [np.float64(0.790970993240597), np.float64(2.60295231683735)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.1385682  -1.96675624  1.20280566]
# Spatial Linear  Velocity: [-0.89174938  1.1385682  -1.96675624]
# Body Angular    Velocity: [1.20280566 2.30838024 0.79097099]
# Body Linear     Velocity: [-1.96675624  1.20280566  2.30838024]
# Joint Positions: [np.float64(2.6628108693727786), np.float64(-1.2307872242058002)]
# Joint Velocities: [np.float64(0.7808826445860593), np.float64(2.628602025078064)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.13360974 -1.98249507  1.21099244]
# Spatial Linear  Velocity: [-0.90558257  1.13360974 -1.98249507]
# Body Angular    Velocity: [1.21099244 2.33303363 0.78088264]
# Body Linear     Velocity: [-1.98249507  1.21099244  2.33303363]
# Joint Positions: [np.float64(2.6643619384250017), np.float64(-1.2255041594533076)]
# Joint Velocities: [np.float64(0.769930485856062), np.float64(2.654549696535525)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.12790437 -1.99829532  1.2192906 ]
# Spatial Linear  Velocity: [-0.91938896  1.12790437 -1.99829532]
# Body Angular    Velocity: [1.2192906  2.3579577  0.76993049]
# Body Linear     Velocity: [-1.99829532  1.2192906   2.3579577 ]
# Joint Positions: [np.float64(2.665891346308838), np.float64(-1.2201692668859765)]
# Joint Velocities: [np.float64(0.7596649431964536), np.float64(2.680282332456501)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.12299922 -2.01376583  1.22746746]
# Spatial Linear  Velocity: [-0.93361146  1.12299922 -2.01376583]
# Body Angular    Velocity: [1.22746746 2.38269532 0.75966494]
# Body Linear     Velocity: [-2.01376583  1.22746746  2.38269532]
# Joint Positions: [np.float64(2.667399585136782), np.float64(-1.2147826791681924)]
# Joint Velocities: [np.float64(0.7487580689381986), np.float64(2.706245169508085)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.11757571 -2.02923718  1.23572756]
# Spatial Linear  Velocity: [-0.94787444  1.11757571 -2.02923718]
# Body Angular    Velocity: [1.23572756 2.40764206 0.74875807]
# Body Linear     Velocity: [-2.02923718  1.23572756  2.40764206]
# Joint Positions: [np.float64(2.668884541708538), np.float64(-1.2093436426357103)]
# Joint Velocities: [np.float64(0.7361651252806943), np.float64(2.732806176770726)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.11061298 -2.04497874  1.24424416]
# Spatial Linear  Velocity: [-0.96188164  1.11061298 -2.04497874]
# Body Angular    Velocity: [1.24424416 2.4331227  0.73616513]
# Body Linear     Velocity: [-2.04497874  1.24424416  2.4331227 ]
# Joint Positions: [np.float64(2.670344549421867), np.float64(-1.203851542306755)]
# Joint Velocities: [np.float64(0.7235947404505665), np.float64(2.7593842074262276)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.1038085  -2.06054876  1.25275685]
# Spatial Linear  Velocity: [-0.97611997  1.1038085  -2.06054876]
# Body Angular    Velocity: [1.25275685 2.4586178  0.72359474]
# Body Linear     Velocity: [-2.06054876  1.25275685  2.4586178 ]
# Joint Positions: [np.float64(2.671780024982625), np.float64(-1.1983064796030767)]
# Joint Velocities: [np.float64(0.711842670682766), np.float64(2.7856945035634526)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.09794258 -2.07573037  1.26113745]
# Spatial Linear  Velocity: [-0.99081723  1.09794258 -2.07573037]
# Body Angular    Velocity: [1.26113745 2.48387322 0.71184267]
# Body Linear     Velocity: [-2.07573037  1.26113745  2.48387322]
# Joint Positions: [np.float64(2.6731921895756448), np.float64(-1.1927088478882157)]
# Joint Velocities: [np.float64(0.7000804811832677), np.float64(2.8120271095618734)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.09219891 -2.09073615  1.26951667]
# Spatial Linear  Velocity: [-1.00574118  1.09219891 -2.09073615]
# Body Angular    Velocity: [1.26951667 2.50914804 0.70008048]
# Body Linear     Velocity: [-2.09073615  1.26951667  2.50914804]
# Joint Positions: [np.float64(2.6745794041250335), np.float64(-1.1870580162095818)]
# Joint Velocities: [np.float64(0.6876928581313928), np.float64(2.83860457730226)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.085982   -2.10572578  1.27800046]
# Spatial Linear  Velocity: [-1.02071863  1.085982   -2.10572578]
# Body Angular    Velocity: [1.27800046 2.53463819 0.68769286]
# Body Linear     Velocity: [-2.10572578  1.27800046  2.53463819]
# Joint Positions: [np.float64(2.675942809181393), np.float64(-1.1813543611794568)]
# Joint Velocities: [np.float64(0.6754757190518725), np.float64(2.865141245669052)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.08007011 -2.12048204  1.2864586 ]
# Spatial Linear  Velocity: [-1.03597745  1.08007011 -2.12048204]
# Body Angular    Velocity: [1.2864586  2.56008958 0.67547572]
# Body Linear     Velocity: [-2.12048204  1.2864586   2.56008958]
# Joint Positions: [np.float64(2.67728115011283), np.float64(-1.1755973792777032)]
# Joint Velocities: [np.float64(0.6628271211460992), np.float64(2.8918589350702875)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.07388274 -2.13516353  1.29499555]
# Spatial Linear  Velocity: [-1.05134899  1.07388274 -2.13516353]
# Body Angular    Velocity: [1.29499555 2.58569809 0.66282712]
# Body Linear     Velocity: [-2.13516353  1.29499555  2.58569809]
# Joint Positions: [np.float64(2.6785943399425216), np.float64(-1.169786996880218)]
# Joint Velocities: [np.float64(0.6503242747030902), np.float64(2.918542009655154)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.06798175 -2.14960536  1.30351646]
# Spatial Linear  Velocity: [-1.06699721  1.06798175 -2.14960536]
# Body Angular    Velocity: [1.30351646 2.61127025 0.65032427]
# Body Linear     Velocity: [-2.14960536  1.30351646  2.61127025]
# Joint Positions: [np.float64(2.679882279923065), np.float64(-1.163923133855149)]
# Joint Velocities: [np.float64(0.6375729176549122), np.float64(2.945340577159331)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.06198918 -2.16391277  1.31209044]
# Spatial Linear  Velocity: [-1.08281332  1.06198918 -2.16391277]
# Body Angular    Velocity: [1.31209044 2.63693947 0.63757292]
# Body Linear     Velocity: [-2.16391277  1.31209044  2.63693947]
# Joint Positions: [np.float64(2.681143375934909), np.float64(-1.158005129416673)]
# Joint Velocities: [np.float64(0.6236623879574458), np.float64(2.9726134612182804)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.05504075 -2.17834221  1.32088269]
# Spatial Linear  Velocity: [-1.09854517  1.05504075 -2.17834221]
# Body Angular    Velocity: [1.32088269 2.66302454 0.62366239]
# Body Linear     Velocity: [-2.17834221  1.32088269  2.66302454]
# Joint Positions: [np.float64(2.6823774717711015), np.float64(-1.1520328778672684)]
# Joint Velocities: [np.float64(0.6105703747811685), np.float64(2.9995875170162583)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.04903397 -2.19232043  1.32955137]
# Spatial Linear  Velocity: [-1.11474472  1.04903397 -2.19232043]
# Body Angular    Velocity: [1.32955137 2.68883217 0.61057037]
# Body Linear     Velocity: [-2.19232043  1.32955137  2.68883217]
# Joint Positions: [np.float64(2.683583719320261), np.float64(-1.1460059884986942)]
# Joint Velocities: [np.float64(0.595642517718683), np.float64(3.0273222161355258)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.0414453  -2.20661555  1.33857026]
# Spatial Linear  Velocity: [-1.13067878  1.0414453  -2.20661555]
# Body Angular    Velocity: [1.33857026 2.71531019 0.59564252]
# Body Linear     Velocity: [-2.20661555  1.33857026  2.71531019]
# Joint Positions: [np.float64(2.684761236163757), np.float64(-1.1399240553190664)]
# Joint Velocities: [np.float64(0.5818261752971636), np.float64(3.0546343634746136)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.03508263 -2.22035697  1.34741958]
# Spatial Linear  Velocity: [-1.1471627   1.03508263 -2.22035697]
# Body Angular    Velocity: [1.34741958 2.74139592 0.58182618]
# Body Linear     Velocity: [-2.22035697  1.34741958  2.74139592]
# Joint Positions: [np.float64(2.685910835980156), np.float64(-1.13378735802286)]
# Joint Velocities: [np.float64(0.5677292808086853), np.float64(3.082085942575654)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.0286249  -2.23394918  1.35634793]
# Spatial Linear  Velocity: [-1.16381441  1.0286249  -2.23394918]
# Body Angular    Velocity: [1.35634793 2.76759355 0.56772928]
# Body Linear     Velocity: [-2.23394918  1.35634793  2.76759355]
# Joint Positions: [np.float64(2.6870313252298508), np.float64(-1.1275953488833386)]
# Joint Velocities: [np.float64(0.5527075518993951), np.float64(3.109949478122443)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.02147512 -2.2475819   1.36548001]
# Spatial Linear  Velocity: [-1.1804602   1.02147512 -2.2475819 ]
# Body Angular    Velocity: [1.36548001 2.79414568 0.55270755]
# Body Linear     Velocity: [-2.2475819   1.36548001  2.79414568]
# Joint Positions: [np.float64(2.6881211692566156), np.float64(-1.1213473292738343)]
# Joint Velocities: [np.float64(0.5370880621182758), np.float64(3.138096019613948)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.01395344 -2.26115291  1.3747647 ]
# Spatial Linear  Velocity: [-1.19719213  1.01395344 -2.26115291]
# Body Angular    Velocity: [1.3747647  2.820934   0.53708806]
# Body Linear     Velocity: [-2.26115291  1.3747647   2.820934  ]
# Joint Positions: [np.float64(2.689180715835657), np.float64(-1.11504338899521)]
# Joint Velocities: [np.float64(0.5222544877890576), np.float64(3.1659366274250695)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.00735476 -2.27423129  1.38394516]
# Spatial Linear  Velocity: [-1.21438584  1.00735476 -2.27423129]
# Body Angular    Velocity: [1.38394516 2.84742876 0.52225449]
# Body Linear     Velocity: [-2.27423129  1.38394516  2.84742876]
# Joint Positions: [np.float64(2.6902093820638395), np.float64(-1.1086832166350353)]
# Joint Velocities: [np.float64(0.5066572414443864), np.float64(3.1941348705107253)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 1.00023932 -2.28728775  1.39331575]
# Spatial Linear  Velocity: [-1.23162454  1.00023932 -2.28728775]
# Body Angular    Velocity: [1.39331575 2.87422491 0.50665724]
# Body Linear     Velocity: [-2.28728775  1.39331575  2.87422491]
# Joint Positions: [np.float64(2.69120712521507), np.float64(-1.1022667351220286)]
# Joint Velocities: [np.float64(0.49117733254942053), np.float64(3.2223112855114997)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.99343058 -2.30004262  1.40271286]
# Spatial Linear  Velocity: [-1.2491464   0.99343058 -2.30004262]
# Body Angular    Velocity: [1.40271286 2.90098029 0.49117733]
# Body Linear     Velocity: [-2.30004262  1.40271286  2.90098029]
# Joint Positions: [np.float64(2.6921738672046054), np.float64(-1.0957938533953304)]
# Joint Velocities: [np.float64(0.4755078389395482), np.float64(3.2506005522892947)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.98664846 -2.31258539  1.41219776]
# Spatial Linear  Velocity: [-1.2668706   0.98664846 -2.31258539]
# Body Angular    Velocity: [1.41219776 2.92781513 0.47550784]
# Body Linear     Velocity: [-2.31258539  1.41219776  2.92781513]
# Joint Positions: [np.float64(2.6931086567762934), np.float64(-1.0892640880882696)]
# Joint Velocities: [np.float64(0.4592233181103315), np.float64(3.279196081786832)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.97951105 -2.32504532  1.42185927]
# Spatial Linear  Velocity: [-1.28468671  0.97951105 -2.32504532]
# Body Angular    Velocity: [1.42185927 2.95490155 0.45922332]
# Body Linear     Velocity: [-2.32504532  1.42185927  2.95490155]
# Joint Positions: [np.float64(2.694009274660016), np.float64(-1.082676367136201)]
# Joint Velocities: [np.float64(0.44133192411902383), np.float64(3.308558926002997)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.97113105 -2.33773799  1.43190535]
# Spatial Linear  Velocity: [-1.30233955  0.97113105 -2.33773799]
# Body Angular    Velocity: [1.43190535 2.98265138 0.44133192]
# Body Linear     Velocity: [-2.33773799  1.43190535  2.98265138]
# Joint Positions: [np.float64(2.6948749999329267), np.float64(-1.0760302951873553)]
# Joint Velocities: [np.float64(0.4243370865242264), np.float64(3.3375450846508983)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.96379659 -2.34984488  1.4418449 ]
# Spatial Linear  Velocity: [-1.32048316  0.96379659 -2.34984488]
# Body Angular    Velocity: [1.4418449  3.01003164 0.42433709]
# Body Linear     Velocity: [-2.34984488  1.4418449   3.01003164]
# Joint Positions: [np.float64(2.695706370452232), np.float64(-1.0693260473589359)]
# Joint Velocities: [np.float64(0.4070896491607164), np.float64(3.366682119876379)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.95646481 -2.36173215  1.45190752]
# Spatial Linear  Velocity: [-1.33881941  0.95646481 -2.36173215]
# Body Angular    Velocity: [1.45190752 3.03751758 0.40708965]
# Body Linear     Velocity: [-2.36173215  1.45190752  3.03751758]
# Joint Positions: [np.float64(2.6965028779894182), np.float64(-1.0625633168596036)]
# Joint Velocities: [np.float64(0.38935150765511894), np.float64(3.3960856358902127)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.94893002 -2.37347195  1.46214701]
# Spatial Linear  Velocity: [-1.35728943  0.94893002 -2.37347195]
# Body Angular    Velocity: [1.46214701 3.06521186 0.38935151]
# Body Linear     Velocity: [-2.37347195  1.46214701  3.06521186]
# Joint Positions: [np.float64(2.6972629046439525), np.float64(-1.0557412616172757)]
# Joint Velocities: [np.float64(0.37060680101265764), np.float64(3.4260083770458536)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.94074524 -2.38522979  1.47267932]
# Spatial Linear  Velocity: [-1.37576589  0.94074524 -2.38522979]
# Body Angular    Velocity: [1.47267932 3.09333946 0.3706068 ]
# Body Linear     Velocity: [-2.38522979  1.47267932  3.09333946]
# Joint Positions: [np.float64(2.6979854609704232), np.float64(-1.04885933135755)]
# Joint Velocities: [np.float64(0.35178453784594044), np.float64(3.4560086001800157)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.93275243 -2.39668694  1.48331993]
# Spatial Linear  Velocity: [-1.3944858   0.93275243 -2.39668694]
# Body Angular    Velocity: [1.48331993 3.12149923 0.35178454]
# Body Linear     Velocity: [-2.39668694  1.48331993  3.12149923]
# Joint Positions: [np.float64(2.6986699667286227), np.float64(-1.0419171636387201)]
# Joint Velocities: [np.float64(0.3326561852799246), np.float64(3.4861979157373537)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.92475609 -2.40791174  1.49412149]
# Spatial Linear  Velocity: [-1.41339291  0.92475609 -2.40791174]
# Body Angular    Velocity: [1.49412149 3.14978997 0.33265619]
# Body Linear     Velocity: [-2.40791174  1.49412149  3.14978997]
# Joint Positions: [np.float64(2.6993158060703015), np.float64(-1.034914374631225)]
# Joint Velocities: [np.float64(0.3131156478614456), np.float64(3.516631712388972)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.91667257 -2.4189324   1.50511254]
# Spatial Linear  Velocity: [-1.43246293  0.91667257 -2.4189324 ]
# Body Angular    Velocity: [1.50511254 3.17825972 0.31311565]
# Body Linear     Velocity: [-2.4189324   1.50511254  3.17825972]
# Joint Positions: [np.float64(2.6999221414622174), np.float64(-1.0278504652989582)]
# Joint Velocities: [np.float64(0.29315018068882015), np.float64(3.5473198310534317)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.90850214 -2.42974492  1.51630281]
# Spatial Linear  Velocity: [-1.45169483  0.90850214 -2.42974492]
# Body Angular    Velocity: [1.51630281 3.20691499 0.29315018]
# Body Linear     Velocity: [-2.42974492  1.51630281  3.20691499]
# Joint Positions: [np.float64(2.700488255819118), np.float64(-1.020724990926673)]
# Joint Velocities: [np.float64(0.2726933319003058), np.float64(3.578300285247352)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.9001989  -2.44036425  1.52771384]
# Spatial Linear  Velocity: [-1.47107502  0.9001989  -2.44036425]
# Body Angular    Velocity: [1.52771384 3.2357879  0.27269333]
# Body Linear     Velocity: [-2.44036425  1.52771384  3.2357879 ]
# Joint Positions: [np.float64(2.7010131136969093), np.float64(-1.013537338269701)]
# Joint Velocities: [np.float64(0.2520829629658522), np.float64(3.6094015383908045)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.89206737 -2.45066212  1.53927885]
# Spatial Linear  Velocity: [-1.49068537  0.89206737 -2.45066212]
# Body Angular    Velocity: [1.53927885 3.26472052 0.25208296]
# Body Linear     Velocity: [-2.45066212  1.53927885  3.26472052]
# Joint Positions: [np.float64(2.701496255960799), np.float64(-1.006287183915378)]
# Joint Velocities: [np.float64(0.23092619496775046), np.float64(3.640829772215008)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.88377882 -2.46076785  1.55109062]
# Spatial Linear  Velocity: [-1.51043458  0.88377882 -2.46076785]
# Body Angular    Velocity: [1.55109062 3.29389729 0.23092619]
# Body Linear     Velocity: [-2.46076785  1.55109062  3.29389729]
# Joint Positions: [np.float64(2.701936221746019), np.float64(-0.9989736749609776)]
# Joint Velocities: [np.float64(0.20895202088880038), np.float64(3.672732936892589)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.87511809 -2.47076796  1.56322016]
# Spatial Linear  Velocity: [-1.53026299  0.87511809 -2.47076796]
# Body Angular    Velocity: [1.56322016 3.3234485  0.20895202]
# Body Linear     Velocity: [-2.47076796  1.56322016  3.3234485 ]
# Joint Positions: [np.float64(2.7023319869352598), np.float64(-0.9915961797223586)]
# Joint Velocities: [np.float64(0.18669220334624714), np.float64(3.70483474702558)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.86655455 -2.4804631   1.57555669]
# Spatial Linear  Velocity: [-1.55029604  0.86655455 -2.4804631 ]
# Body Angular    Velocity: [1.57555669 3.35312118 0.1866922 ]
# Body Linear     Velocity: [-2.4804631   1.57555669  3.35312118]
# Joint Positions: [np.float64(2.702682755452471), np.float64(-0.9841541782788336)]
# Joint Velocities: [np.float64(0.1639617765052961), np.float64(3.7372365884076557)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.85794387 -2.48990897  1.58814968]
# Spatial Linear  Velocity: [-1.57049295  0.85794387 -2.48990897]
# Body Angular    Velocity: [1.58814968 3.38300427 0.16396178]
# Body Linear     Velocity: [-2.48990897  1.58814968  3.38300427]
# Joint Positions: [np.float64(2.7029873254523706), np.float64(-0.9766469243544412)]
# Joint Velocities: [np.float64(0.14053263384035566), np.float64(3.7700668376840003)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.84911057 -2.49917721  1.6010615 ]
# Spatial Linear  Velocity: [-1.59080533  0.84911057 -2.49917721]
# Body Angular    Velocity: [1.6010615  3.41321052 0.14053263]
# Body Linear     Velocity: [-2.49917721  1.6010615   3.41321052]
# Joint Positions: [np.float64(2.7032445735225945), np.float64(-0.9690737057829147)]
# Joint Velocities: [np.float64(0.11662571686818557), np.float64(3.803209710236955)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.84025703 -2.50817642  1.61425071]
# Spatial Linear  Velocity: [-1.61128491  0.84025703 -2.50817642]
# Body Angular    Velocity: [1.61425071 3.44363162 0.11662572]
# Body Linear     Velocity: [-2.50817642  1.61425071  3.44363162]
# Joint Positions: [np.float64(2.7034534554250587), np.float64(-0.9614338443606887)]
# Joint Velocities: [np.float64(0.09218241513160849), np.float64(3.8367014096962504)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.83135064 -2.51691622  1.62774039]
# Spatial Linear  Velocity: [-1.63192089  0.83135064 -2.51691622]
# Body Angular    Velocity: [1.62774039 3.4742969  0.09218242]
# Body Linear     Velocity: [-2.51691622  1.62774039  3.4742969 ]
# Joint Positions: [np.float64(2.7036129047399013), np.float64(-0.9537266417802138)]
# Joint Velocities: [np.float64(0.06715977002030774), np.float64(3.870570511484592)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.82237334 -2.52540041  1.64155065]
# Spatial Linear  Velocity: [-1.65270638  0.82237334 -2.52540041]
# Body Angular    Velocity: [1.64155065 3.5052286  0.06715977]
# Body Linear     Velocity: [-2.52540041  1.64155065  3.5052286 ]
# Joint Positions: [np.float64(2.703721929643531), np.float64(-0.9459514344283665)]
# Joint Velocities: [np.float64(0.04176614984851906), np.float64(3.904702242729741)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.81351257 -2.53353907  1.65564074]
# Spatial Linear  Velocity: [-1.67368673  0.81351257 -2.53353907]
# Body Angular    Velocity: [1.65564074 3.53631918 0.04176615]
# Body Linear     Velocity: [-2.53353907  1.65564074  3.53631918]
# Joint Positions: [np.float64(2.703779403069384), np.float64(-0.9381074721019291)]
# Joint Velocities: [np.float64(0.015493195659764314), np.float64(3.9393927565230142)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.80437328 -2.54150858  1.67014489]
# Spatial Linear  Velocity: [-1.69475915  0.80437328 -2.54150858]
# Body Angular    Velocity: [1.67014489 3.56783286 0.0154932 ]
# Body Linear     Velocity: [-2.54150858  1.67014489  3.56783286]
# Joint Positions: [np.float64(2.7037836543601976), np.float64(-0.9301936828527271)]
# Joint Velocities: [np.float64(-0.011348611637680254), np.float64(3.974467958121191)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.79522954 -2.54917833  1.68500007]
# Spatial Linear  Velocity: [-1.71599009  0.79522954 -2.54917833]
# Body Angular    Velocity: [ 1.68500007  3.59960697 -0.01134861]
# Body Linear     Velocity: [-2.54917833  1.68500007  3.59960697]
# Joint Positions: [np.float64(2.7037331907648157), np.float64(-0.9222090821782876)]
# Joint Velocities: [np.float64(-0.03916709262261726), np.float64(4.010172934167877)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.78577731 -2.55668731  1.70032069]
# Spatial Linear  Velocity: [-1.73730172  0.78577731 -2.55668731]
# Body Angular    Velocity: [ 1.70032069  3.63185855 -0.03916709]
# Body Linear     Velocity: [-2.55668731  1.70032069  3.63185855]
# Joint Positions: [np.float64(2.7036268005844604), np.float64(-0.9141528433512054)]
# Joint Velocities: [np.float64(-0.0672634518110009), np.float64(4.04609964180129)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.77659541 -2.56375671  1.71594352]
# Spatial Linear  Velocity: [-1.75883322  0.77659541 -2.56375671]
# Body Angular    Velocity: [ 1.71594352  3.66421344 -0.06726345]
# Body Linear     Velocity: [-2.56375671  1.71594352  3.66421344]
# Joint Positions: [np.float64(2.703463477756651), np.float64(-0.9060242493417852)]
# Joint Velocities: [np.float64(-0.09634794255595726), np.float64(4.082677470185775)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.76714291 -2.57064123  1.73205995]
# Spatial Linear  Velocity: [-1.78045011  0.76714291 -2.57064123]
# Body Angular    Velocity: [ 1.73205995  3.69705608 -0.09634794]
# Body Linear     Velocity: [-2.57064123  1.73205995  3.69705608]
# Joint Positions: [np.float64(2.7032413016258223), np.float64(-0.8978220287618406)]
# Joint Velocities: [np.float64(-0.12607041111707223), np.float64(4.1197008533800705)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.75772186 -2.57718995  1.74859578]
# Spatial Linear  Velocity: [-1.80222156  0.75772186 -2.57718995]
# Body Angular    Velocity: [ 1.74859578  3.73019409 -0.12607041]
# Body Linear     Velocity: [-2.57718995  1.74859578  3.73019409]
# Joint Positions: [np.float64(2.70295917829773), np.float64(-0.8895453975079156)]
# Joint Velocities: [np.float64(-0.1561950449254378), np.float64(4.1570286656177595)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.74853662 -2.58329579  1.76550131]
# Spatial Linear  Velocity: [-1.82419102  0.74853662 -2.58329579]
# Body Angular    Velocity: [ 1.76550131  3.76349471 -0.15619504]
# Body Linear     Velocity: [-2.58329579  1.76550131  3.76349471]
# Joint Positions: [np.float64(2.7026151988693177), np.float64(-0.8811930553692502)]
# Joint Velocities: [np.float64(-0.18791946884360564), np.float64(4.1954074842728275)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.73869312 -2.58940042  1.78310731]
# Spatial Linear  Velocity: [-1.84614792  0.73869312 -2.58940042]
# Body Angular    Velocity: [ 1.78310731  3.79762719 -0.18791947]
# Body Linear     Velocity: [-2.58940042  1.78310731  3.79762719]
# Joint Positions: [np.float64(2.7022072220845446), np.float64(-0.872763551485392)]
# Joint Velocities: [np.float64(-0.22021486108937754), np.float64(4.234206614370356)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.72901474 -2.59508774  1.80116101]
# Spatial Linear  Velocity: [-1.86827882  0.72901474 -2.59508774]
# Body Angular    Velocity: [ 1.80116101  3.83201314 -0.22021486]
# Body Linear     Velocity: [-2.59508774  1.80116101  3.83201314]
# Joint Positions: [np.float64(2.7017337489533837), np.float64(-0.8642558139911944)]
# Joint Velocities: [np.float64(-0.2535943250639792), np.float64(4.273755176671727)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.71914066 -2.60053675  1.8198154 ]
# Spatial Linear  Velocity: [-1.89049832  0.71914066 -2.60053675]
# Body Angular    Velocity: [ 1.8198154   3.86694391 -0.25359433]
# Body Linear     Velocity: [-2.60053675  1.8198154   3.86694391]
# Joint Positions: [np.float64(2.70119220392511), np.float64(-0.8556680783156717)]
# Joint Velocities: [np.float64(-0.28812206941108964), np.float64(4.314102122718323)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.70906027 -2.60574927  1.83910923]
# Spatial Linear  Velocity: [-1.91280081  0.70906027 -2.60574927]
# Body Angular    Velocity: [ 1.83910923  3.90245491 -0.28812207]
# Body Linear     Velocity: [-2.60574927  1.83910923  3.90245491]
# Joint Positions: [np.float64(2.70058188720273), np.float64(-0.8469997674822406)]
# Joint Velocities: [np.float64(-0.3225894649460479), np.float64(4.354475645412106)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.69969925 -2.61023617  1.85872421]
# Spatial Linear  Velocity: [-1.93538127  0.69969925 -2.61023617]
# Body Angular    Velocity: [ 1.85872421  3.93784236 -0.32258946]
# Body Linear     Velocity: [-2.61023617  1.85872421  3.93784236]
# Joint Positions: [np.float64(2.6999002975523734), np.float64(-0.8382491250992552)]
# Joint Velocities: [np.float64(-0.358929509247254), np.float64(4.396131918280929)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.68966245 -2.61472549  1.87921458]
# Spatial Linear  Velocity: [-1.95793576  0.68966245 -2.61472549]
# Body Angular    Velocity: [ 1.87921458  3.97423306 -0.35892951]
# Body Linear     Velocity: [-2.61472549  1.87921458  3.97423306]
# Joint Positions: [np.float64(2.699144930320508), np.float64(-0.8294143794258936)]
# Joint Velocities: [np.float64(-0.39635401964955436), np.float64(4.438569870951507)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.67957527 -2.61888414  1.90038598]
# Spatial Linear  Velocity: [-1.98059399  0.67957527 -2.61888414]
# Body Angular    Velocity: [ 1.90038598  4.01116387 -0.39635402]
# Body Linear     Velocity: [-2.61888414  1.90038598  4.01116387]
# Joint Positions: [np.float64(2.698313536191123), np.float64(-0.8204939037807588)]
# Joint Velocities: [np.float64(-0.43462860220669924), np.float64(4.481640000082957)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.66964532 -2.62259367  1.92219313]
# Spatial Linear  Velocity: [-2.00339212  0.66964532 -2.62259367]
# Body Angular    Velocity: [ 1.92219313  4.04848992 -0.4346286 ]
# Body Linear     Velocity: [-2.62259367  1.92219313  4.04848992]
# Joint Positions: [np.float64(2.697405040193369), np.float64(-0.8114868472248027)]
# Joint Velocities: [np.float64(-0.47439557076789973), np.float64(4.525784128469369)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.65945147 -2.62608281  1.94484018]
# Spatial Linear  Velocity: [-2.02624258  0.65945147 -2.62608281]
# Body Angular    Velocity: [ 1.94484018  4.08660233 -0.47439557]
# Body Linear     Velocity: [-2.62608281  1.94484018  4.08660233]
# Joint Positions: [np.float64(2.6964163978611873), np.float64(-0.8023910168864276)]
# Joint Velocities: [np.float64(-0.5154596811167267), np.float64(4.570880891722793)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.64918299 -2.62924337  1.96829885]
# Spatial Linear  Velocity: [-2.04917805  0.64918299 -2.62924337]
# Body Angular    Velocity: [ 1.96829885  4.12537898 -0.51545968]
# Body Linear     Velocity: [-2.62924337  1.96829885  4.12537898]
# Joint Positions: [np.float64(2.6953430298456533), np.float64(-0.7932031558177614)]
# Joint Velocities: [np.float64(-0.5581500831240036), np.float64(4.617159416663481)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.63866465 -2.63216557  1.99269891]
# Spatial Linear  Velocity: [-2.0721587   0.63866465 -2.63216557]
# Body Angular    Velocity: [ 1.99269891  4.16501046 -0.55815008]
# Body Linear     Velocity: [-2.63216557  1.99269891  4.16501046]
# Joint Positions: [np.float64(2.6941845182063533), np.float64(-0.7839228292062347)]
# Joint Velocities: [np.float64(-0.6010071358663337), np.float64(4.6636272505823335)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.62894865 -2.63425095  2.01762617]
# Spatial Linear  Velocity: [-2.09537173  0.62894865 -2.63425095]
# Body Angular    Velocity: [ 2.01762617  4.20459317 -0.60100714]
# Body Linear     Velocity: [-2.63425095  2.01762617  4.20459317]
# Joint Positions: [np.float64(2.6929398161794356), np.float64(-0.7745491708652484)]
# Joint Velocities: [np.float64(-0.6439255269093848), np.float64(4.710203231382313)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.62012717 -2.63543001  2.0430605 ]
# Spatial Linear  Velocity: [-2.11881553  0.62012717 -2.63543001]
# Body Angular    Velocity: [ 2.0430605   4.24404504 -0.64392553]
# Body Linear     Velocity: [-2.63543001  2.0430605   4.24404504]
# Joint Positions: [np.float64(2.6916089552852736), np.float64(-0.7650820747776818)]
# Joint Velocities: [np.float64(-0.6871702668264421), np.float64(4.757070125412913)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.61203906 -2.63578297  2.06909172]
# Spatial Linear  Velocity: [-2.14244515  0.61203906 -2.63578297]
# Body Angular    Velocity: [ 2.06909172  4.28352374 -0.68717027]
# Body Linear     Velocity: [-2.63578297  2.06909172  4.28352374]
# Joint Positions: [np.float64(2.690186234186643), np.float64(-0.755517367684063)]
# Joint Velocities: [np.float64(-0.7358054828735632), np.float64(4.807829147446793)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.60137338 -2.63724953  2.09732657]
# Spatial Linear  Velocity: [-2.16570684  0.60137338 -2.63724953]
# Body Angular    Velocity: [ 2.09732657  4.32625038 -0.73580548]
# Body Linear     Velocity: [-2.63724953  2.09732657  4.32625038]
# Joint Positions: [np.float64(2.6886678515148033), np.float64(-0.7458522235428756)]
# Joint Velocities: [np.float64(-0.7834340871091565), np.float64(4.8579436029529015)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.59246148 -2.63727274  2.125823  ]
# Spatial Linear  Velocity: [-2.18930436  0.59246148 -2.63727274]
# Body Angular    Velocity: [ 2.125823    4.36812232 -0.78343409]
# Body Linear     Velocity: [-2.63727274  2.125823    4.36812232]
# Joint Positions: [np.float64(2.68705037450133), np.float64(-0.7360840123182653)]
# Joint Velocities: [np.float64(-0.834325325716968), np.float64(4.910483080539863)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.58255324 -2.63748298  2.15595307]
# Spatial Linear  Velocity: [-2.2127919   0.58255324 -2.63748298]
# Body Angular    Velocity: [ 2.15595307  4.41188287 -0.83432533]
# Body Linear     Velocity: [-2.63748298  2.15595307  4.41188287]
# Joint Positions: [np.float64(2.6853280084224833), np.float64(-0.7262083814828628)]
# Joint Velocities: [np.float64(-0.8883388168362792), np.float64(4.96537638765724)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.57185187 -2.63776457  2.18773463]
# Spatial Linear  Velocity: [-2.23620569  0.57185187 -2.63776457]
# Body Angular    Velocity: [ 2.18773463  4.45744096 -0.88833882]
# Body Linear     Velocity: [-2.63776457  2.18773463  4.45744096]
# Joint Positions: [np.float64(2.683497041474325), np.float64(-0.7162224645891775)]
# Joint Velocities: [np.float64(-0.943682314481549), np.float64(5.021331566834864)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.5615897  -2.63736403  2.22063805]
# Spatial Linear  Velocity: [-2.25971852  0.5615897  -2.63736403]
# Body Angular    Velocity: [ 2.22063805  4.50361381 -0.94368231]
# Body Linear     Velocity: [-2.63736403  2.22063805  4.50361381]
# Joint Positions: [np.float64(2.681553432746364), np.float64(-0.7061231207093067)]
# Joint Velocities: [np.float64(-1.0003021918056791), np.float64(5.078308789695466)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.55186486 -2.63620617  2.25468404]
# Spatial Linear  Velocity: [-2.2833253   0.55186486 -2.63620617]
# Body Angular    Velocity: [ 2.25468404  4.55034285 -1.00030219]
# Body Linear     Velocity: [-2.63620617  2.25468404  4.55034285]
# Joint Positions: [np.float64(2.679502276983348), np.float64(-0.6959140121723636)]
# Joint Velocities: [np.float64(-1.0526715952168528), np.float64(5.132175432910766)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.54608685 -2.63213751  2.2880276 ]
# Spatial Linear  Velocity: [-2.30742797  0.54608685 -2.63213751]
# Body Angular    Velocity: [ 2.2880276   4.59392582 -1.0526716 ]
# Body Linear     Velocity: [-2.63213751  2.2880276   4.59392582]
# Joint Positions: [np.float64(2.677334667958203), np.float64(-0.6855882778613498)]
# Joint Velocities: [np.float64(-1.1153100749316067), np.float64(5.193850940435894)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.5354689  -2.63069994  2.32559584]
# Spatial Linear  Velocity: [-2.33093762  0.5354689  -2.63069994]
# Body Angular    Velocity: [ 2.32559584  4.64410288 -1.11531007]
# Body Linear     Velocity: [-2.63069994  2.32559584  4.64410288]
# Joint Positions: [np.float64(2.6750447137564337), np.float64(-0.6751413407986478)]
# Joint Velocities: [np.float64(-1.1777812489557902), np.float64(5.255490483730854)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0.52649642 -2.62777743  2.36395034]
# Spatial Linear  Velocity: [-2.35462853  0.52649642 -2.62777743]
# Body Angular    Velocity: [ 2.36395034  4.6938171  -1.17778125]
# Body Linear     Velocity: [-2.62777743  2.36395034  4.6938171 ]
# Joint Positions: [np.float64(2.6726257633430466), np.float64(-0.6645679737958348)]
# Joint Velocities: [np.float64(-1.2416698713145011), np.float64(5.318278124301724)]
# --------------------------------------------------
# Spatial Angular Velocity: [ 0